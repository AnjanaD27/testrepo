# %%
import numpy as np
import pandas as pd

# %%
xp="C:\\Users\\ANJANA\\Documents\\python-program\\market-analysis\\market analysis\\Sample - Superstore.xls"
dataset=pd.read_excel(xp)

# %%
dataset.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
dataset.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %%
market_analysis=dataset.reindex(columns=['Order Date','Category'])
market_analysis.head()
# Out:
#   Order Date         Category
# 0 2016-11-08        Furniture
# 1 2016-11-08        Furniture
# 2 2016-06-12  Office Supplies
# 3 2015-10-11        Furniture
# 4 2015-10-11  Office Supplies

# %%
type('Order Date')
# Out:
# str

# %%
dataset['Order Date'] =pd.to_datetime(dataset['Order Date'])
dataset.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
type('Order Date')
# Out:
# str

# %%
da=market_analysis[market_analysis['Category']=='Furniture']
da.head()
# Out:
#    Order Date   Category
# 0  2016-11-08  Furniture
# 1  2016-11-08  Furniture
# 3  2015-10-11  Furniture
# 5  2014-06-09  Furniture
# 10 2014-06-09  Furniture

# %%
reorder_data=da.set_index('Order Date')
reorder_data.head()
# Out:
#              Category
# Order Date
# 2016-11-08  Furniture
# 2016-11-08  Furniture
# 2015-10-11  Furniture
# 2014-06-09  Furniture
# 2014-06-09  Furniture

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
reorder_data.Category.resample('M').count().plot(kind='bar',figsize=(12,4),color='purple')
plt.ylabel('Furniture Sales')
plt.title('Furniture sales using OrderDates monthly wise')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
reorder_data.Category.resample('BQ').count().plot(kind='bar',color='red',figsize=(12,4))
plt.ylabel('Furniture Sales')
plt.title('Furniture sales using OrderDatesQuarterly wise')
plt.grid(True,color='b')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
reorder_data.Category.resample('A').count().plot(kind='bar',figsize=(12,4),color='c')
plt.ylabel('Furniture Sales')
plt.title('Furniture sales using OrderDates monthly wise')
plt.grid(True)
plt.legend()
plt.show()

# %%
sal=dataset.reindex(columns=['Order Date','Sales'])
sal.head()
# Out:
#   Order Date     Sales
# 0 2016-11-08  261.9600
# 1 2016-11-08  731.9400
# 2 2016-06-12   14.6200
# 3 2015-10-11  957.5775
# 4 2015-10-11   22.3680

# %%
sale=sal.set_index('Order Date')
sale.head()
# Out:
#                Sales
# Order Date
# 2016-11-08  261.9600
# 2016-11-08  731.9400
# 2016-06-12   14.6200
# 2015-10-11  957.5775
# 2015-10-11   22.3680

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
sales_rate = sale['Sales']

# %%
sale.Sales.resample('M').mean().plot()

# %%
#using additive model and seasonal_decompose 
import matplotlib.pyplot as plt
# %matplotlib inline
plt.figure(figsize=(12,4))
x=sale.Sales.resample('W').mean()
result = seasonal_decompose(x, model='additive')
#print(result.trend)
result.plot()
plt.show()

# %%
q=dataset.reindex(columns=['Order Date','Quantity'])
q.head()
# Out:
#   Order Date  Quantity
# 0 2016-11-08         2
# 1 2016-11-08         3
# 2 2016-06-12         2
# 3 2015-10-11         5
# 4 2015-10-11         2

# %%
quantity=q.set_index('Order Date')
quantity.head()
# Out:
#             Quantity
# Order Date
# 2016-11-08         2
# 2016-11-08         3
# 2016-06-12         2
# 2015-10-11         5
# 2015-10-11         2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
quantity.Quantity.resample('M').mean().plot(figsize=(14,6))
plt.ylabel('Furniture Quantity')
plt.title('furniture quantity using order date(monthly).')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
quantity.Quantity.resample('W').mean().plot(color='purple',figsize=(14,6))
plt.ylabel('Furniture Quantity')
plt.title('furniture quantity using order date(weekly).')
plt.grid(True,color='black')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
quantity.Quantity.resample('A').mean().plot(color='blue',figsize=(14,6))
plt.ylabel('Furniture Quantity')
plt.title('furniture quantity using order date(yearly).')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
df_category = dataset[["Category", "Sales"]]
df_category.groupby('Category').sum().plot(kind="bar",color='red',figsize=(12,4))
plt.ylabel("sales")
plt.title('graph for sales according to catogery.')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
df_category = dataset[["Sub-Category", "Sales"]]
df_category.groupby('Sub-Category').sum().plot(kind="bar",color='red',figsize=(12,4))
plt.ylabel("sales")
plt.title('graph for sales according to sub-catogery.')
plt.grid(True)
plt.legend()
plt.show()
